# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# ## Nhập dữ liệu từ file csv ngăn cách bởi dấu ;

# %%
df = pd.read_csv("feinstaub_14.2.csv", sep = ";")

# %%
df.head(5)
# Out:
#    sensor_id sensor_type  location     lat     lon            timestamp  \
# 0      15216      SDS011      7711  46.634  14.318  2021-02-14T00:00:26
# 1      15216      SDS011      7711  46.634  14.318  2021-02-14T00:02:53
# 2      15216      SDS011      7711  46.634  14.318  2021-02-14T00:05:20
# 3      15216      SDS011      7711  46.634  14.318  2021-02-14T00:07:47
# 4      15216      SDS011      7711  46.634  14.318  2021-02-14T00:10:14
#
#       P1  durP1  ratioP1    P2  durP2  ratioP2
# 0  15.20    NaN      NaN  7.27    NaN      NaN
# 1  15.33    NaN      NaN  7.27    NaN      NaN
# 2  16.57    NaN      NaN  7.17    NaN      NaN
# 3  12.57    NaN      NaN  6.80    NaN      NaN
# 4  11.43    NaN      NaN  5.00    NaN      NaN

# %% [markdown]
# Phan tich xem P1 la PM10 va P2 la PM2.5 co dung kO? chac la dung roi :v

# %%
#df = df.drop(['durP1', 'durP2', 'ratioP1', 'ratioP2'], axis=1)
df = df.drop(columns=['durP1', 'durP2', 'ratioP1', 'ratioP2'])
df[df['P1'] < 2]
# Out:
#      sensor_id sensor_type  location     lat     lon            timestamp  \
# 217      15216      SDS011      7711  46.634  14.318  2021-02-14T09:28:50
# 224      15216      SDS011      7711  46.634  14.318  2021-02-14T09:46:34
# 229      15216      SDS011      7711  46.634  14.318  2021-02-14T09:59:30
# 230      15216      SDS011      7711  46.634  14.318  2021-02-14T10:02:08
# 231      15216      SDS011      7711  46.634  14.318  2021-02-14T10:04:37
# 236      15216      SDS011      7711  46.634  14.318  2021-02-14T10:16:51
# 255      15216      SDS011      7711  46.634  14.318  2021-02-14T11:03:39
# 256      15216      SDS011      7711  46.634  14.318  2021-02-14T11:06:25
# 261      15216      SDS011      7711  46.634  14.318  2021-02-14T11:18:40
# 289      15216      SDS011      7711  46.634  14.318  2021-02-14T12:27:19
# 290      15216      SDS011      7711  46.634  14.318  2021-02-14T12:29:45
# 291      15216      SDS011      7711  46.634  14.318  2021-02-14T12:32:12
# ...

# %%
list(df.columns)
# Out:
# ['sensor_id',
#  'sensor_type',
#  'location',
#  'lat',
#  'lon',
#  'timestamp',
#  'P1',
#  'durP1',
#  'ratioP1',
#  'P2',
#  'durP2',
#  'ratioP2']

# %%
import plotly.express as px
fig = px.scatter(df, x='timestamp', y='P1')
fig.show()
