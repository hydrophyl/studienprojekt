# %%
import pandas as pd

df = pd.read_csv("data-esp8266-12776407-2021-11-09.csv", sep=";")

# %%
df.head()
# Out:
#                   Time  durP1  ratioP1  P1  durP2  ratioP2  P2  SDS_P1  \
# 0  2021/11/09 00:01:50    NaN      NaN NaN    NaN      NaN NaN    4.70
# 1  2021/11/09 00:04:15    NaN      NaN NaN    NaN      NaN NaN    4.13
# 2  2021/11/09 00:06:43    NaN      NaN NaN    NaN      NaN NaN    4.25
# 3  2021/11/09 00:09:15    NaN      NaN NaN    NaN      NaN NaN    2.47
# 4  2021/11/09 00:11:40    NaN      NaN NaN    NaN      NaN NaN    2.60
#
#    SDS_P2  PMS_P1  ...  BMP_pressure  BME280_temperature  BME280_humidity  \
# 0    1.00     NaN  ...           NaN                 NaN              NaN
# 1    1.00     NaN  ...           NaN                 NaN              NaN
# 2    1.00     NaN  ...           NaN                 NaN              NaN
# 3    0.80     NaN  ...           NaN                 NaN              NaN
# 4    0.88     NaN  ...           NaN                 NaN              NaN
#
#    BME280_pressure  Samples  Min_cycle  Max_cycle  Signal  HPM_P1  HPM_P2
# ...

# %%
df.drop(columns=['durP1', 'ratioP1'])
# Out:
#                     Time  P1  durP2  ratioP2  P2  SDS_P1  SDS_P2  PMS_P1  \
# 0    2021/11/09 00:01:50 NaN    NaN      NaN NaN    4.70    1.00     NaN
# 1    2021/11/09 00:04:15 NaN    NaN      NaN NaN    4.13    1.00     NaN
# 2    2021/11/09 00:06:43 NaN    NaN      NaN NaN    4.25    1.00     NaN
# 3    2021/11/09 00:09:15 NaN    NaN      NaN NaN    2.47    0.80     NaN
# 4    2021/11/09 00:11:40 NaN    NaN      NaN NaN    2.60    0.88     NaN
# ..                   ...  ..    ...      ...  ..     ...     ...     ...
# 259  2021/11/09 12:46:35 NaN    NaN      NaN NaN    4.60    1.90     NaN
# 260  2021/11/09 12:49:02 NaN    NaN      NaN NaN    5.10    1.73     NaN
# 261  2021/11/09 12:51:39 NaN    NaN      NaN NaN    5.35    2.05     NaN
# 262  2021/11/09 12:54:09 NaN    NaN      NaN NaN    3.47    1.55     NaN
# 263  2021/11/09 12:56:37 NaN    NaN      NaN NaN    5.28    1.80     NaN
#
#      PMS_P2  Temp  ...  BMP_pressure  BME280_temperature  BME280_humidity  \
# ...

# %%
df.to_csv("export.csv", sep=",")
